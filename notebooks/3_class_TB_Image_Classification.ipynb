# %% [markdown]
# # MLX Image Classification Benchmarking
#
# An image classification notebook for the `mlx` program

# %%
import os

REPO_URL = "https://github.com/ralampay/mlx.git"
REPO_DIR = "/content/mlx"

if os.path.exists(REPO_DIR):
  # %cd {REPO_DIR}
  # !git pull
else:
  # !git clone {REPO_URL} {REPO_DIR}
  # %cd {REPO_DIR}

# !pip install -q -r requirements.txt
# Out:
# /content/mlx
# Already up to date.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
import os

DATASET_ZIP_URL = "https://alive-research.s3.ap-southeast-1.amazonaws.com/tbx11k-classification-3-class-seed-42.zip"
DATA_DIR = "/content/datasets"
ZIP_PATH = f"{DATA_DIR}/dataset.zip"
DATASET_NAME = "tb-3-class-seed-42-image-classification"
SEED = 42

# !mkdir -p {DATA_DIR}

if not os.path.exists(ZIP_PATH):
  # !wget -O {ZIP_PATH} "{DATASET_ZIP_URL}"
else:
  print(f"Dataset already downloaded to {ZIP_PATH}")

print(f"DATA_DIR: {DATA_DIR}")
# Out:
# Dataset already downloaded to /content/datasets/dataset.zip
# DATA_DIR: /content/datasets

# %%
import os
import zipfile

EXTRACT_DIR = f"{DATA_DIR}/image-classification/tbx11k-classification-3-class-seed-42"

os.makedirs(EXTRACT_DIR, exist_ok=True)

# Check if the directory is empty or if it exists with content
# This assumes that if the directory exists and is not empty, extraction has already occurred.
# A more robust check might involve checking for specific files/subdirectories expected after extraction.
if not os.path.exists(EXTRACT_DIR) or not os.listdir(EXTRACT_DIR):
  with zipfile.ZipFile(ZIP_PATH, "r") as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)
  print("Extracted to:", EXTRACT_DIR)
else:
  print(f"Data already extracted to {EXTRACT_DIR}")

print("Top-level contents:", os.listdir(EXTRACT_DIR))

train_dir = f"{EXTRACT_DIR}/train"

print("Found class directories in:", train_dir)
print("First 10 class names:", os.listdir(train_dir)[:10])
# Out:
# Data already extracted to /content/datasets/image-classification/tbx11k-classification-3-class-seed-42
# Top-level contents: ['train', 'val', 'test']
# Found class directories in: /content/datasets/image-classification/tbx11k-classification-3-class-seed-42/train
# First 10 class names: ['healthy', 'sick-non-tb', 'tb']

# %%
NUM_CLASSES = len(os.listdir(train_dir))
OUTPUT_DATASET = EXTRACT_DIR

print(f"Output Dataset: {OUTPUT_DATASET}")
print(f"Number of classes: {NUM_CLASSES}")
# Out:
# Output Dataset: /content/datasets/image-classification/tbx11k-classification-3-class-seed-42
# Number of classes: 3

# %%
EPOCHS = 100
DEVICE = "cuda"
BATCH_SIZE = 16

models = [
    # "efficientnet_b0",
    # "mobilenet_v3_large",
    # "drax_mobilenet_v3_large",
    # "densenet121",
    "resnet18",
    "draxnet",
    "resnet50",
    # "convnext_tiny",
    # "convnext_small",
    # "convnext_base"
]

for model_name in models:
    MODEL_NAME = model_name
    RUN_NAME = f"{SEED}-{DATASET_NAME}-{MODEL_NAME}"
    ARTIFACTS_DIR = f"/content/artifacts/{RUN_NAME}"
    BENCHMARK_DIR = f"/content/benchmark/{SEED}-{DATASET_NAME}-{MODEL_NAME}"
    CHECKPOINT_PATH = f"{ARTIFACTS_DIR}/{MODEL_NAME}.pth"

    print(f"\n--- Starting training for model: {MODEL_NAME} ---")
    # !python -m mlx \
      --mode image_classification \
      --action train \
      --dataset "{OUTPUT_DATASET}" \
      --output "{ARTIFACTS_DIR}" \
      --model "{MODEL_NAME}" \
      --epochs "{EPOCHS}" \
      --batch-size "{BATCH_SIZE}" \
      --device "{DEVICE}" \
      --height 512 --width 512 \
      --seed "{SEED}"

    print(f"Training artifacts for {MODEL_NAME} saved to: {ARTIFACTS_DIR}")

    print(f"\n--- Starting benchmarking for model: {MODEL_NAME} ---")
    # !mkdir -p "{BENCHMARK_DIR}"

    # !python -m mlx \
      --mode image_classification \
      --action benchmark \
      --dataset "{OUTPUT_DATASET}" \
      --model {MODEL_NAME} \
      --model-path "{CHECKPOINT_PATH}" \
      --output "{BENCHMARK_DIR}" \
      --batch-size "{BATCH_SIZE}" \
      --device "{DEVICE}"

    print(f"Benchmark results for {MODEL_NAME} saved to: {BENCHMARK_DIR}")

    import os

    print(f"Benchmark files for {MODEL_NAME}:")
    if os.path.exists(BENCHMARK_DIR):
      for name in sorted(os.listdir(BENCHMARK_DIR)):
        print("-", name)
    else:
      print("  No benchmark directory found.")
# Out:
# --- Starting training for model: resnet18 ---
# Using global random seed=42
# ╭─────────── MLX ────────────╮
# │ Mode: image_classification │
# │ Action: train              │
# │ Model: resnet18            │
# ╰────────────────────────────╯
#                      Configuration for resnet18 (standard)
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃          Parameter ┃ Value                                                   ┃
# ┡━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │             action │ train                                                   │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │         batch_size │ 16                                                      │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │            colored │ True                                                    │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │       dataset_path │ /content/datasets/image-classification/tbx11k-classifi… │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │             device │ cuda                                                    │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │     embedding_size │ 4096                                                    │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │             epochs │ 100                                                     │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │         input_size │ (512, 512)                                              │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │                 lr │ None                                                    │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │          num_pairs │ 100                                                     │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │         pretrained │ False                                                   │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │        random_seed │ 42                                                      │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │ refresh_per_second │ 2                                                       │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │            verbose │ False                                                   │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │               mode │ image_classification                                    │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │              model │ resnet18                                                │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │             height │ 512                                                     │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │              width │ 512                                                     │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │        output_path │ /content/artifacts/42-tb-3-class-seed-42-image-classif… │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │        train_count │ None                                                    │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │          val_count │ None                                                    │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │         test_count │ None                                                    │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │        train_ratio │ None                                                    │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │          val_ratio │ None                                                    │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │         test_ratio │ None                                                    │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │         split_mode │ None                                                    │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │          overwrite │ False                                                   │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │         model_path │ None                                                    │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │          file_path │ None                                                    │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │          input_img │ /tmp/image.jpg                                          │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │         confidence │ 0.25                                                    │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │       camera_index │ 0                                                       │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │                lr0 │ None                                                    │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │          optimizer │ auto                                                    │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │                nbs │ 64                                                      │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │      warmup_epochs │ 3.0                                                     │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │                amp │ True                                                    │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │          loss_clip │ None                                                    │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │           run_name │ None                                                    │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │        num_classes │ 2                                                       │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │     mask_threshold │ 0.5                                                     │
# ├────────────────────┼─────────────────────────────────────────────────────────┤
# │      overlay_alpha │ 0.45                                                    │
# └────────────────────┴─────────────────────────────────────────────────────────┘
# Starting standard classification training on device=cuda for 100 epochs
# Epoch 1/100  loss: 0.417162  val_loss: 0.538183  accuracy: 0.802381  precision:
# 0.878274  recall: 0.619737  f1: 0.621127
# Saved new best model at
# /content/artifacts/42-tb-3-class-seed-42-image-classification-resnet18/resnet18.
# pth

# %%
import os
from google.colab import drive

# Define the source directory to be zipped
source_dir = "/content/benchmark"
# Define the output zip file path
output_zip_file = f"/content/{SEED}-benchmark.zip"

# Ensure the old version is overridden by removing it if it exists
if os.path.exists(output_zip_file):
  # !rm -f "{output_zip_file}"
  print(f"Removed existing {output_zip_file}")

# Zip the directory recursively
# !zip -r "{output_zip_file}" "{source_dir}"

print(f"Successfully zipped '{source_dir}' to '{output_zip_file}'")

# Mount Google Drive
if not os.path.exists('/content/drive'):
  drive.mount('/content/drive')
else:
  print("Google Drive already mounted.")

# Define the destination path in Google Drive
gdrive_destination_path = f"/content/drive/MyDrive/{os.path.basename(output_zip_file)}"

# Copy the zip file to Google Drive
# !cp "{output_zip_file}" "{gdrive_destination_path}"

print(f"Successfully copied '{output_zip_file}' to '{gdrive_destination_path}'")

# %%
import os
from google.colab import drive

# Define the source directory to be zipped (the created dataset)
source_dataset_dir = OUTPUT_DATASET
# Define the output zip file path
output_dataset_zip_file = f"/content/{os.path.basename(OUTPUT_DATASET)}.zip"

# Ensure the old version is overridden by removing it if it exists
if os.path.exists(output_dataset_zip_file):
  # !rm -f "{output_dataset_zip_file}"
  print(f"Removed existing {output_dataset_zip_file}")

# Zip the dataset directory recursively
if os.path.exists(source_dataset_dir):
  # !zip -r "{output_dataset_zip_file}" "{source_dataset_dir}"
  print(f"Successfully zipped '{source_dataset_dir}' to '{output_dataset_zip_file}'")
else:
  print(f"Dataset directory '{source_dataset_dir}' does not exist. Skipping zip operation.")

# Mount Google Drive
if not os.path.exists('/content/drive'):
  drive.mount('/content/drive')
else:
  print("Google Drive already mounted.")

# Define the destination path in Google Drive
gdrive_dataset_destination_path = f"/content/drive/MyDrive/{os.path.basename(output_dataset_zip_file)}"

# Copy the zip file to Google Drive if it was created
if os.path.exists(output_dataset_zip_file):
  # !cp "{output_dataset_zip_file}" "{gdrive_dataset_destination_path}"
  print(f"Successfully copied '{output_dataset_zip_file}' to '{gdrive_dataset_destination_path}'")
else:
  print("No dataset zip file was created, skipping copy to Google Drive.")

# %% [markdown]
# # MLX Image Classification Benchmarking
#
# An image classification notebook for the `mlx` program

# %%
import os

REPO_URL = "https://github.com/ralampay/mlx.git"
BASE_DIR = "/home/ralampay/workspace/mlx/tmp"
REPO_DIR = f"/{BASE_DIR}/mlx"

if os.path.exists(REPO_DIR):
  # %cd {REPO_DIR}
  # !git pull
else:
  # !git clone {REPO_URL} {REPO_DIR}
  # %cd {REPO_DIR}

# !pip install -q -r requirements.txt
# Out:
# /home/ralampay/workspace/mlx/tmp/mlx
# Already up to date.
#
# [notice] A new release of pip is available: 26.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os

DATASET_ZIP_URL = "https://alive-research.s3.ap-southeast-1.amazonaws.com/tbx11k-classification-3-class-seed-42.zip"
DATA_DIR = f"{BASE_DIR}/datasets"
ZIP_PATH = f"{DATA_DIR}/dataset-3-class-tb.zip"
DATASET_NAME = "tb-3-class-seed-42-image-classification"
SEED = 42

# !mkdir -p {DATA_DIR}

if not os.path.exists(ZIP_PATH):
  # !wget -O {ZIP_PATH} "{DATASET_ZIP_URL}"
else:
  print(f"Dataset already downloaded to {ZIP_PATH}")

print(f"DATA_DIR: {DATA_DIR}")
# Out:
# Dataset already downloaded to /home/ralampay/workspace/mlx/tmp/datasets/dataset-3-class-tb.zip
# DATA_DIR: /home/ralampay/workspace/mlx/tmp/datasets

# %%
import os
import zipfile

EXTRACT_DIR = f"{DATA_DIR}/image-classification/"

os.makedirs(EXTRACT_DIR, exist_ok=True)

# Check if the directory is empty or if it exists with content
# This assumes that if the directory exists and is not empty, extraction has already occurred.
# A more robust check might involve checking for specific files/subdirectories expected after extraction.
if not os.path.exists(EXTRACT_DIR) or not os.listdir(EXTRACT_DIR):
  with zipfile.ZipFile(ZIP_PATH, "r") as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)
  print("Extracted to:", EXTRACT_DIR)
else:
  print(f"Data already extracted to {EXTRACT_DIR}")

print("Top-level contents:", os.listdir(EXTRACT_DIR))

train_dir = f"{EXTRACT_DIR}/tbx11k-classification-3-class-seed-42/train"

print("Found class directories in:", train_dir)
print("First 10 class names:", os.listdir(train_dir)[:10])
# Out:
# Data already extracted to /home/ralampay/workspace/mlx/tmp/datasets/image-classification/
# Top-level contents: ['tbx11k-classification-3-class-seed-42']
# Found class directories in: /home/ralampay/workspace/mlx/tmp/datasets/image-classification//tbx11k-classification-3-class-seed-42/train
# First 10 class names: ['sick-non-tb', 'healthy', 'tb']

# %%
NUM_CLASSES = len(os.listdir(train_dir))
OUTPUT_DATASET = f"{EXTRACT_DIR}tbx11k-classification-3-class-seed-42"

print(f"Output Dataset: {OUTPUT_DATASET}")
print(f"Number of classes: {NUM_CLASSES}")
# Out:
# Output Dataset: /home/ralampay/workspace/mlx/tmp/datasets/image-classification/tbx11k-classification-3-class-seed-42
# Number of classes: 3

# %%
EPOCHS = 100
DEVICE = "cuda"
BATCH_SIZE = 16

models = [
    "efficientnet_b0",
    "mobilenet_v3_large",
    "drax_mobilenet_v3_large",
    "densenet121",
    "resnet18",
    "draxnet",
    "resnet50",
    "convnext_tiny",
    "convnext_small"
    "convnext_base"
]

for model_name in models:
    MODEL_NAME = model_name
    RUN_NAME = f"{SEED}-{DATASET_NAME}-{MODEL_NAME}"
    ARTIFACTS_DIR = f"{BASE_DIR}/artifacts/{RUN_NAME}"
    BENCHMARK_DIR = f"{BASE_DIR}/benchmark/{SEED}-{DATASET_NAME}-{MODEL_NAME}"
    CHECKPOINT_PATH = f"{ARTIFACTS_DIR}/{MODEL_NAME}.pth"

    print(f"\n--- Starting training for model: {MODEL_NAME} ---")
    # !python -m mlx \
      --mode image_classification \
      --action train \
      --dataset "{OUTPUT_DATASET}" \
      --output "{ARTIFACTS_DIR}" \
      --model "{MODEL_NAME}" \
      --epochs "{EPOCHS}" \
      --batch-size "{BATCH_SIZE}" \
      --device "{DEVICE}" \
      --use-best \
      --height 512 --width 512 \
      --seed "{SEED}"

    print(f"Training artifacts for {MODEL_NAME} saved to: {ARTIFACTS_DIR}")

    print(f"\n--- Starting benchmarking for model: {MODEL_NAME} ---")
    # !mkdir -p "{BENCHMARK_DIR}"

    # !python -m mlx \
      --mode image_classification \
      --action benchmark \
      --dataset "{OUTPUT_DATASET}" \
      --model {MODEL_NAME} \
      --model-path "{CHECKPOINT_PATH}" \
      --output "{BENCHMARK_DIR}" \
      --batch-size "{BATCH_SIZE}" \
      --device "{DEVICE}"

    print(f"Benchmark results for {MODEL_NAME} saved to: {BENCHMARK_DIR}")

    import os

    print(f"Benchmark files for {MODEL_NAME}:")
    if os.path.exists(BENCHMARK_DIR):
      for name in sorted(os.listdir(BENCHMARK_DIR)):
        print("-", name)
    else:
      print("  No benchmark directory found.")
# Out:
# --- Starting training for model: efficientnet_b0 ---
# Using global random seed=42
# ╭─────────── MLX ────────────╮
# │ Mode: image_classification │
# │ Action: train              │
# │ Model: efficientnet_b0     │
# ╰────────────────────────────╯
#                   Configuration for efficientnet_b0 (standard)
# ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃             Parameter ┃ Value                                                ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │                action │ train                                                │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │ apply_transformations │ False                                                │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            batch_size │ 16                                                   │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │               colored │ True                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │          dataset_path │ /home/ralampay/workspace/mlx/tmp/datasets/image-cla… │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                device │ cuda                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │        embedding_size │ 4096                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                epochs │ 100                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            input_size │ (512, 512)                                           │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                    lr │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             num_pairs │ 100                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            pretrained │ False                                                │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │           random_seed │ 42                                                   │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │    refresh_per_second │ 2                                                    │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │              use_best │ True                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │               verbose │ False                                                │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                  mode │ image_classification                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                 model │ efficientnet_b0                                      │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                height │ 512                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                 width │ 512                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │           output_path │ /home/ralampay/workspace/mlx/tmp/artifacts/42-tb-3-… │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │           train_count │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             val_count │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            test_count │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │           train_ratio │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             val_ratio │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            test_ratio │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            split_mode │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             overwrite │ False                                                │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            model_path │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             file_path │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             input_img │ /tmp/image.jpg                                       │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            confidence │ 0.25                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │          camera_index │ 0                                                    │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                   lr0 │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             optimizer │ auto                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                   nbs │ 64                                                   │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │         warmup_epochs │ 3.0                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                   amp │ True                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             loss_clip │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │              run_name │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │           num_classes │ 2                                                    │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │        mask_threshold │ 0.5                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │         overlay_alpha │ 0.45                                                 │
# └───────────────────────┴──────────────────────────────────────────────────────┘
# Starting standard classification training on device=cuda for 100 epochs
# Epoch 1/100  loss: 0.344027  val_loss: 0.287805  accuracy: 0.936508  precision:
# 0.943507  recall: 0.845760  f1: 0.879725
# Saved new best model at
# /home/ralampay/workspace/mlx/tmp/artifacts/42-tb-3-class-seed-42-image-classific
# ation-efficientnet_b0/efficientnet_b0.pth
# Epoch 2/100  loss: 0.223801  val_loss: 0.166034  accuracy: 0.949206  precision:
# 0.964400  recall: 0.850731  f1: 0.888088
# Saved new best model at
# /home/ralampay/workspace/mlx/tmp/artifacts/42-tb-3-class-seed-42-image-classific
# ation-efficientnet_b0/efficientnet_b0.pth
# Epoch 3/100  loss: 0.171343  val_loss: 0.128962  accuracy: 0.957937  precision:
# 0.960280  recall: 0.879094  f1: 0.909754
# Saved new best model at
# /home/ralampay/workspace/mlx/tmp/artifacts/42-tb-3-class-seed-42-image-classific
# ation-efficientnet_b0/efficientnet_b0.pth
# Epoch 4/100  loss: 0.140740  val_loss: 0.108572  accuracy: 0.969048  precision:
# 0.972094  recall: 0.913596  f1: 0.938008
# Saved new best model at
# /home/ralampay/workspace/mlx/tmp/artifacts/42-tb-3-class-seed-42-image-classific
# ation-efficientnet_b0/efficientnet_b0.pth
# Epoch 5/100  loss: 0.095261  val_loss: 0.085381  accuracy: 0.971429  precision:
# 0.976434  recall: 0.913158  f1: 0.939204
# Saved new best model at
# /home/ralampay/workspace/mlx/tmp/artifacts/42-tb-3-class-seed-42-image-classific
# ation-efficientnet_b0/efficientnet_b0.pth
# Epoch 6/100  loss: 0.107588  val_loss: 0.311763  accuracy: 0.915873  precision:
# 0.939303  recall: 0.891959  f1: 0.910329
# Epoch 7/100  loss: 0.106344  val_loss: 0.085529  accuracy: 0.969841  precision:
# 0.954216  recall: 0.938304  f1: 0.945854
# Epoch 8/100  loss: 0.071620  val_loss: 0.047780  accuracy: 0.984127  precision:
# 0.978864  recall: 0.961988  f1: 0.970036
# Saved new best model at
# /home/ralampay/workspace/mlx/tmp/artifacts/42-tb-3-class-seed-42-image-classific
# ation-efficientnet_b0/efficientnet_b0.pth
# Epoch 9/100  loss: 0.066483  val_loss: 0.381737  accuracy: 0.946825  precision:
# 0.948136  recall: 0.888450  f1: 0.912682
# Epoch 10/100  loss: 0.065988  val_loss: 0.086442  accuracy: 0.963492  precision:
# 0.937568  recall: 0.911696  f1: 0.923555
# Epoch 11/100  loss: 0.056742  val_loss: 0.121811  accuracy: 0.957937  precision:
# 0.945565  recall: 0.929532  f1: 0.936956
# Epoch 12/100  loss: 0.066551  val_loss: 0.109258  accuracy: 0.965873  precision:
# 0.963695  recall: 0.911257  f1: 0.933506
# Epoch 13/100  loss: 0.058376  val_loss: 0.055294  accuracy: 0.984127  precision:
# 0.978795  recall: 0.959795  f1: 0.968795
# Epoch 14/100  loss: 0.047928  val_loss: 0.046044  accuracy: 0.986508  precision:
# 0.981062  recall: 0.974708  f1: 0.977823
# Saved new best model at
# /home/ralampay/workspace/mlx/tmp/artifacts/42-tb-3-class-seed-42-image-classific
# precision: 0.987519  recall: 0.985380  f1: 0.986441
# Standard classification training complete!
# Training artifacts for efficientnet_b0 saved to: /home/ralampay/workspace/mlx/tmp/artifacts/42-tb-3-class-seed-42-image-classification-efficientnet_b0
#
# --- Starting benchmarking for model: efficientnet_b0 ---
# ╭─────────── MLX ────────────╮
# │ Mode: image_classification │
# │ Action: benchmark          │
# │ Model: efficientnet_b0     │
# ╰────────────────────────────╯
#                   Configuration for efficientnet_b0 (standard)
# ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃             Parameter ┃ Value                                                ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │                action │ benchmark                                            │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │ apply_transformations │ False                                                │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            batch_size │ 16                                                   │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │               colored │ True                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │          dataset_path │ /home/ralampay/workspace/mlx/tmp/datasets/image-cla… │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                device │ cuda                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │        embedding_size │ 4096                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                epochs │ 100                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            input_size │ (256, 256)                                           │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                    lr │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             num_pairs │ 100                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            pretrained │ False                                                │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │           random_seed │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │    refresh_per_second │ 2                                                    │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │              use_best │ False                                                │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │               verbose │ False                                                │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                  mode │ image_classification                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                 model │ efficientnet_b0                                      │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                height │ 256                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                 width │ 256                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │           output_path │ /home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-… │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │           train_count │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             val_count │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            test_count │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │           train_ratio │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             val_ratio │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            test_ratio │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            split_mode │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             overwrite │ False                                                │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            model_path │ /home/ralampay/workspace/mlx/tmp/artifacts/42-tb-3-… │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             file_path │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             input_img │ /tmp/image.jpg                                       │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            confidence │ 0.25                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │          camera_index │ 0                                                    │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                   lr0 │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             optimizer │ auto                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                   nbs │ 64                                                   │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │         warmup_epochs │ 3.0                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                   amp │ True                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             loss_clip │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │              run_name │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │           num_classes │ 2                                                    │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │        mask_threshold │ 0.5                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │         overlay_alpha │ 0.45                                                 │
# └───────────────────────┴──────────────────────────────────────────────────────┘
# Loaded 1260 labelled images from
# /home/ralampay/workspace/mlx/tmp/datasets/image-classification/tbx11k-classifica
# tion-3-class-seed-42/test
# Evaluating images: 100%|████████████████████████| 79/79 [00:08<00:00,  9.26it/s]
#         Benchmark Results
# ┏━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓
# ┃ Metric               ┃  Score ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩
# │ Accuracy             │ 0.9889 │
# │ Ave Precision        │ 0.9829 │
# │ Ave Recall           │ 0.9787 │
# │ F1-score             │ 0.9807 │
# │ ROC AUC (macro)      │ 0.9994 │
# │ ROC AUC (weighted)   │ 0.9994 │
# └──────────────────────┴────────┘
#                  Per-Class Metrics
# ┏━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━┓
# ┃ Class       ┃    AUC ┃ Sensitivity ┃ Specificity ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━┩
# │ healthy     │ 0.9994 │      0.9912 │      0.9986 │
# │ sick-non-tb │ 0.9993 │      0.9947 │      0.9870 │
# │ tb          │ 0.9995 │      0.9500 │      0.9965 │
# └─────────────┴────────┴─────────────┴─────────────┘
# Benchmark artifacts written to
# /home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classific
# ation-efficientnet_b0
# Benchmark results for efficientnet_b0 saved to: /home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-efficientnet_b0
# Benchmark files for efficientnet_b0:
# - confusion_matrix.csv
# - confusion_matrix.png
# - metrics.csv
# - roc_curve.png
#
# --- Starting training for model: mobilenet_v3_large ---
# Using global random seed=42
# ╭─────────── MLX ────────────╮
# │ Mode: image_classification │
# │ Action: train              │
# │ Model: mobilenet_v3_large  │
# ╰────────────────────────────╯
#                 Configuration for mobilenet_v3_large (standard)
# ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃             Parameter ┃ Value                                                ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │                action │ train                                                │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │ apply_transformations │ False                                                │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            batch_size │ 16                                                   │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │               colored │ True                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │          dataset_path │ /home/ralampay/workspace/mlx/tmp/datasets/image-cla… │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                device │ cuda                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │        embedding_size │ 4096                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                epochs │ 100                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            input_size │ (512, 512)                                           │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                    lr │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             num_pairs │ 100                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            pretrained │ False                                                │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │           random_seed │ 42                                                   │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │    refresh_per_second │ 2                                                    │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │              use_best │ True                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │               verbose │ False                                                │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                  mode │ image_classification                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                 model │ mobilenet_v3_large                                   │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                height │ 512                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                 width │ 512                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │           output_path │ /home/ralampay/workspace/mlx/tmp/artifacts/42-tb-3-… │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │           train_count │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             val_count │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            test_count │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │           train_ratio │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             val_ratio │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            test_ratio │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            split_mode │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             overwrite │ False                                                │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            model_path │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             file_path │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             input_img │ /tmp/image.jpg                                       │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            confidence │ 0.25                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │          camera_index │ 0                                                    │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                   lr0 │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             optimizer │ auto                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                   nbs │ 64                                                   │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │         warmup_epochs │ 3.0                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                   amp │ True                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             loss_clip │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │              run_name │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │           num_classes │ 2                                                    │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │        mask_threshold │ 0.5                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │         overlay_alpha │ 0.45                                                 │
# └───────────────────────┴──────────────────────────────────────────────────────┘
# Starting standard classification training on device=cuda for 100 epochs
# Epoch 1/100  loss: 0.294182  val_loss: 1.247624  accuracy: 0.452381  precision:
# 0.150794  recall: 0.333333  f1: 0.207650
# Saved new best model at
# /home/ralampay/workspace/mlx/tmp/artifacts/42-tb-3-class-seed-42-image-classific
# ation-mobilenet_v3_large/mobilenet_v3_large.pth
# Epoch 2/100  loss: 0.185095  val_loss: 0.275606  accuracy: 0.915873  precision:
# 0.937278  recall: 0.863450  f1: 0.890974
# Saved new best model at
# /home/ralampay/workspace/mlx/tmp/artifacts/42-tb-3-class-seed-42-image-classific
# ation-mobilenet_v3_large/mobilenet_v3_large.pth
# Epoch 3/100  loss: 0.136051  val_loss: 1.472887  accuracy: 0.518254  precision:
# 0.616334  recall: 0.645029  f1: 0.494125
# Epoch 4/100  loss: 0.101399  val_loss: 1.057822  accuracy: 0.678571  precision:
# 0.680501  recall: 0.697368  f1: 0.594413
# Epoch 5/100  loss: 0.084761  val_loss: 0.096494  accuracy: 0.965873  precision:
# 0.942284  recall: 0.944152  f1: 0.943210
# Saved new best model at
# /home/ralampay/workspace/mlx/tmp/artifacts/42-tb-3-class-seed-42-image-classific
# ation-mobilenet_v3_large/mobilenet_v3_large.pth
# Epoch 6/100  loss: 0.097291  val_loss: 0.137621  accuracy: 0.957143  precision:
# 0.948845  recall: 0.917982  f1: 0.931769
# Epoch 7/100  loss: 0.095675  val_loss: 0.353147  accuracy: 0.892063  precision:
# 0.932453  recall: 0.817398  f1: 0.854606
# Epoch 8/100  loss: 0.057908  val_loss: 0.636585  accuracy: 0.775397  precision:
# Epoch 85/100  loss: 0.011775  val_loss: 0.168336  accuracy: 0.977778  precision:
# 0.983997  recall: 0.937573  f1: 0.957914
# Epoch 86/100  loss: 0.007688  val_loss: 0.105677  accuracy: 0.978571  precision:
# 0.957372  recall: 0.968860  f1: 0.962928
# Epoch 87/100  loss: 0.010865  val_loss: 0.128612  accuracy: 0.976984  precision:
# 0.980632  recall: 0.943567  f1: 0.960281
# Epoch 88/100  loss: 0.009202  val_loss: 0.124948  accuracy: 0.980159  precision:
# 0.971430  recall: 0.959064  f1: 0.965036
# Epoch 89/100  loss: 0.010592  val_loss: 0.125632  accuracy: 0.983333  precision:
# 0.983040  recall: 0.961404  f1: 0.971577
# Epoch 90/100  loss: 0.010489  val_loss: 0.179510  accuracy: 0.972222  precision:
# 0.974464  recall: 0.926901  f1: 0.947545
# Epoch 91/100  loss: 0.004555  val_loss: 0.141352  accuracy: 0.978571  precision:
# 0.976668  recall: 0.944737  f1: 0.959315
# Epoch 92/100  loss: 0.017156  val_loss: 0.116490  accuracy: 0.980952  precision:
# 0.978653  recall: 0.953070  f1: 0.964973
# Epoch 93/100  loss: 0.012057  val_loss: 0.129499  accuracy: 0.980952  precision:
# 0.983662  recall: 0.948684  f1: 0.964530
# Epoch 94/100  loss: 0.005160  val_loss: 0.120882  accuracy: 0.978571  precision:
# 0.972384  recall: 0.955702  f1: 0.963644
# Epoch 95/100  loss: 0.008984  val_loss: 0.131644  accuracy: 0.979365  precision:
# 0.975070  recall: 0.951901  f1: 0.962753
# Epoch 96/100  loss: 0.006956  val_loss: 0.142239  accuracy: 0.976984  precision:
# 0.973013  recall: 0.941374  f1: 0.955795
# Epoch 97/100  loss: 0.000928  val_loss: 0.175565  accuracy: 0.976984  precision:
# 0.973082  recall: 0.943567  f1: 0.957118
# Epoch 98/100  loss: 0.005816  val_loss: 0.123963  accuracy: 0.980159  precision:
# 0.969321  recall: 0.959064  f1: 0.964030
# Epoch 99/100  loss: 0.013392  val_loss: 0.138430  accuracy: 0.975397  precision:
# 0.954839  recall: 0.964327  f1: 0.959438
# Epoch 100/100  loss: 0.011596  val_loss: 0.095029  accuracy: 0.980952
# precision: 0.976604  recall: 0.961842  f1: 0.968929
# Standard classification training complete!
# Training artifacts for convnext_tiny saved to: /home/ralampay/workspace/mlx/tmp/artifacts/42-tb-3-class-seed-42-image-classification-convnext_tiny
#
# --- Starting benchmarking for model: convnext_tiny ---
# ╭─────────── MLX ────────────╮
# │ Mode: image_classification │
# │ Action: benchmark          │
# │ Model: convnext_tiny       │
# ╰────────────────────────────╯
#                    Configuration for convnext_tiny (standard)
# ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃             Parameter ┃ Value                                                ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │                action │ benchmark                                            │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │ apply_transformations │ False                                                │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            batch_size │ 16                                                   │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │               colored │ True                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │          dataset_path │ /home/ralampay/workspace/mlx/tmp/datasets/image-cla… │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                device │ cuda                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │        embedding_size │ 4096                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                epochs │ 100                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            input_size │ (256, 256)                                           │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                    lr │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             num_pairs │ 100                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            pretrained │ False                                                │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │           random_seed │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │    refresh_per_second │ 2                                                    │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │              use_best │ False                                                │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │               verbose │ False                                                │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                  mode │ image_classification                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                 model │ convnext_tiny                                        │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                height │ 256                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                 width │ 256                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │           output_path │ /home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-… │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │           train_count │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             val_count │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            test_count │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │           train_ratio │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             val_ratio │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            test_ratio │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            split_mode │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             overwrite │ False                                                │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            model_path │ /home/ralampay/workspace/mlx/tmp/artifacts/42-tb-3-… │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             file_path │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             input_img │ /tmp/image.jpg                                       │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │            confidence │ 0.25                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │          camera_index │ 0                                                    │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                   lr0 │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             optimizer │ auto                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                   nbs │ 64                                                   │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │         warmup_epochs │ 3.0                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │                   amp │ True                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │             loss_clip │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │              run_name │ None                                                 │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │           num_classes │ 2                                                    │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │        mask_threshold │ 0.5                                                  │
# ├───────────────────────┼──────────────────────────────────────────────────────┤
# │         overlay_alpha │ 0.45                                                 │
# └───────────────────────┴──────────────────────────────────────────────────────┘
# Loaded 1260 labelled images from
# /home/ralampay/workspace/mlx/tmp/datasets/image-classification/tbx11k-classifica
# tion-3-class-seed-42/test
# Evaluating images: 100%|████████████████████████| 79/79 [00:18<00:00,  4.35it/s]
#         Benchmark Results
# ┏━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓
# ┃ Metric               ┃  Score ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩
# │ Accuracy             │ 0.9714 │
# │ Ave Precision        │ 0.9363 │
# │ Ave Recall           │ 0.9658 │
# │ F1-score             │ 0.9497 │
# │ ROC AUC (macro)      │ 0.9971 │
# │ ROC AUC (weighted)   │ 0.9977 │
# └──────────────────────┴────────┘
#                  Per-Class Metrics
# ┏━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━┓
# ┃ Class       ┃    AUC ┃ Sensitivity ┃ Specificity ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━┩
# │ healthy     │ 0.9988 │      0.9860 │      0.9913 │
# │ sick-non-tb │ 0.9972 │      0.9614 │      0.9899 │
# │ tb          │ 0.9952 │      0.9500 │      0.9798 │
# └─────────────┴────────┴─────────────┴─────────────┘
# Benchmark artifacts written to
# /home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classific
# ation-convnext_tiny
# Benchmark results for convnext_tiny saved to: /home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-convnext_tiny
# Benchmark files for convnext_tiny:
# - confusion_matrix.csv
# - confusion_matrix.png
# - metrics.csv
# - roc_curve.png
#
# --- Starting training for model: convnext_smallconvnext_base ---
# Using global random seed=42
# ╭─────────────── MLX ────────────────╮
# │ Mode: image_classification         │
# │ Action: train                      │
# │ Model: convnext_smallconvnext_base │
# ╰────────────────────────────────────╯
# ╭─────────────────────────────────── Error ────────────────────────────────────╮
# │ Unsupported image-classification model 'convnext_smallconvnext_base'.        │
# │ Available models: convnext_base, convnext_large, convnext_small,             │
# │ convnext_tiny, densenet121, drax_mobilenet_v3_large, draxnet,                │
# │ efficientnet_b0, mobilenet_v3_large, resnet18, resnet50, siamese-le-net.     │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Training artifacts for convnext_smallconvnext_base saved to: /home/ralampay/workspace/mlx/tmp/artifacts/42-tb-3-class-seed-42-image-classification-convnext_smallconvnext_base
#
# --- Starting benchmarking for model: convnext_smallconvnext_base ---
# ╭─────────────── MLX ────────────────╮
# │ Mode: image_classification         │
# │ Action: benchmark                  │
# │ Model: convnext_smallconvnext_base │
# ╰────────────────────────────────────╯
# ╭─────────────────────────────────── Error ────────────────────────────────────╮
# │ Unsupported image-classification model 'convnext_smallconvnext_base'.        │
# │ Available models: convnext_base, convnext_large, convnext_small,             │
# │ convnext_tiny, densenet121, drax_mobilenet_v3_large, draxnet,                │
# │ efficientnet_b0, mobilenet_v3_large, resnet18, resnet50, siamese-le-net.     │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Benchmark results for convnext_smallconvnext_base saved to: /home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-convnext_smallconvnext_base
# Benchmark files for convnext_smallconvnext_base:

# %%
import os

# Define the source directory to be zipped
source_dir = f"{BASE_DIR}/benchmark"
# Define the output zip file path
output_zip_file = f"{BASE_DIR}/{SEED}-benchmark-{DATASET_NAME}.zip"

# Ensure the old version is overridden by removing it if it exists
if os.path.exists(output_zip_file):
  # !rm -f "{output_zip_file}"
  print(f"Removed existing {output_zip_file}")

# Zip the directory recursively
# !zip -r "{output_zip_file}" "{source_dir}"

print(f"Successfully zipped '{source_dir}' to '{output_zip_file}'")
# Out:
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/ (stored 0%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-drax_mobilenet_v3_large/ (stored 0%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-drax_mobilenet_v3_large/confusion_matrix.csv (deflated 20%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-drax_mobilenet_v3_large/metrics.csv (deflated 55%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-drax_mobilenet_v3_large/roc_curve.png (deflated 19%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-drax_mobilenet_v3_large/confusion_matrix.png (deflated 18%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-convnext_smallconvnext_base/ (stored 0%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-mobilenet_v3_large/ (stored 0%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-mobilenet_v3_large/confusion_matrix.csv (deflated 21%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-mobilenet_v3_large/metrics.csv (deflated 56%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-mobilenet_v3_large/roc_curve.png (deflated 19%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-mobilenet_v3_large/confusion_matrix.png (deflated 18%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-densenet121/ (stored 0%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-densenet121/confusion_matrix.csv (deflated 20%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-densenet121/metrics.csv (deflated 54%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-densenet121/roc_curve.png (deflated 19%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-densenet121/confusion_matrix.png (deflated 19%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-resnet18/ (stored 0%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-resnet18/confusion_matrix.csv (deflated 21%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-resnet18/metrics.csv (deflated 54%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-resnet18/roc_curve.png (deflated 19%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-resnet18/confusion_matrix.png (deflated 18%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-resnet50/ (stored 0%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-resnet50/confusion_matrix.csv (deflated 18%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-resnet50/metrics.csv (deflated 55%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-resnet50/roc_curve.png (deflated 19%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-resnet50/confusion_matrix.png (deflated 18%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-convnext_tiny/ (stored 0%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-convnext_tiny/confusion_matrix.csv (deflated 18%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-convnext_tiny/metrics.csv (deflated 53%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-convnext_tiny/roc_curve.png (deflated 19%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-convnext_tiny/confusion_matrix.png (deflated 18%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-efficientnet_b0/ (stored 0%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-efficientnet_b0/confusion_matrix.csv (deflated 21%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-efficientnet_b0/metrics.csv (deflated 55%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-efficientnet_b0/roc_curve.png (deflated 19%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-efficientnet_b0/confusion_matrix.png (deflated 18%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-draxnet/ (stored 0%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-draxnet/confusion_matrix.csv (deflated 18%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-draxnet/metrics.csv (deflated 56%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-draxnet/roc_curve.png (deflated 19%)
#   adding: home/ralampay/workspace/mlx/tmp/benchmark/42-tb-3-class-seed-42-image-classification-draxnet/confusion_matrix.png (deflated 18%)
# Successfully zipped '/home/ralampay/workspace/mlx/tmp/benchmark' to '/home/ralampay/workspace/mlx/tmp/42-benchmark-tb-3-class-seed-42-image-classification.zip'
